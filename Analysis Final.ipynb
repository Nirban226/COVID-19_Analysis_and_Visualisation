# %%
import plotly.io as pio
pio.renderers.default = "png"  # Forces static image output

# %%
# Data analysis and Manipulation
import plotly.graph_objs as go
import plotly.io as pio
import plotly.express as px
import pandas as pd

# Data Visualization
import matplotlib.pyplot as plt

# Importing Plotly
import plotly.offline as py
py.init_notebook_mode(connected=True)

# Initializing Plotly
pio.renderers.default = 'vscode'
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.0.min"</script>

# %%
# Importing Dataset1
dataset1 = pd.read_csv("covid.csv")
dataset1.head()  # returns first 5 rows
# Out:
#   Country/Region      Continent    Population  TotalCases  NewCases  \
# 0            USA  North America  3.311981e+08     5032179       NaN
# 1         Brazil  South America  2.127107e+08     2917562       NaN
# 2          India           Asia  1.381345e+09     2025409       NaN
# 3         Russia         Europe  1.459409e+08      871894       NaN
# 4   South Africa         Africa  5.938157e+07      538184       NaN
#
#    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 0     162804.0        NaN       2576668.0           NaN    2292707.0
# 1      98644.0        NaN       2047660.0           NaN     771258.0
# 2      41638.0        NaN       1377384.0           NaN     606387.0
# 3      14606.0        NaN        676357.0           NaN     180931.0
# 4       9604.0        NaN        387316.0           NaN     141264.0
#
#    Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 0           18296.0           15194.0          492.0  63139605.0
# ...

# %%
# Returns tuple of shape (Rows, columns)
print(dataset1.shape)

# Returns size of dataframe
print(dataset1.size)
# Out:
# (209, 17)
# 3553

# %%
# Information about Dataset1
# return concise summary of dataframe
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country/Region    209 non-null    object
#  1   Continent         208 non-null    object
#  2   Population        208 non-null    float64
#  3   TotalCases        209 non-null    int64
#  4   NewCases          4 non-null      float64
#  5   TotalDeaths       188 non-null    float64
#  6   NewDeaths         3 non-null      float64
#  7   TotalRecovered    205 non-null    float64
#  8   NewRecovered      3 non-null      float64
#  9   ActiveCases       205 non-null    float64
#  10  Serious,Critical  122 non-null    float64
#  11  Tot Cases/1M pop  208 non-null    float64
#  12  Deaths/1M pop     187 non-null    float64
#  13  TotalTests        191 non-null    float64
#  14  Tests/1M pop      191 non-null    float64
#  15  WHO Region        184 non-null    object
# ...

# %%
# Importing Dataset2
dataset2 = pd.read_csv("covid_grouped.csv")
dataset2.head()  # return first 5 rows of dataset2
# Out:
#          Date Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0  2020-01-22    Afghanistan          0       0          0       0          0
# 1  2020-01-22        Albania          0       0          0       0          0
# 2  2020-01-22        Algeria          0       0          0       0          0
# 3  2020-01-22        Andorra          0       0          0       0          0
# 4  2020-01-22         Angola          0       0          0       0          0
#
#    New deaths  New recovered             WHO Region iso_alpha
# 0           0              0  Eastern Mediterranean       AFG
# 1           0              0                 Europe       ALB
# 2           0              0                 Africa       DZA
# 3           0              0                 Europe       AND
# 4           0              0                 Africa       AGO

# %%
# Returns tuple of shape (Rows, columns)
print(dataset2.shape)

# Returns size of dataframe
print(dataset2.size)
# Out:
# (35156, 11)
# 386716

# %%
# Information about Dataset2
dataset2.info()  # return concise summary of dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35156 entries, 0 to 35155
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            35156 non-null  object
#  1   Country/Region  35156 non-null  object
#  2   Confirmed       35156 non-null  int64
#  3   Deaths          35156 non-null  int64
#  4   Recovered       35156 non-null  int64
#  5   Active          35156 non-null  int64
#  6   New cases       35156 non-null  int64
#  7   New deaths      35156 non-null  int64
#  8   New recovered   35156 non-null  int64
#  9   WHO Region      35156 non-null  object
#  10  iso_alpha       35156 non-null  object
# dtypes: int64(7), object(4)
# memory usage: 3.0+ MB

# %%
# Columns labels of a Dataset1
dataset1.columns
# Out:
# Index(['Country/Region', 'Continent', 'Population', 'TotalCases', 'NewCases',
#        'TotalDeaths', 'NewDeaths', 'TotalRecovered', 'NewRecovered',
#        'ActiveCases', 'Serious,Critical', 'Tot Cases/1M pop', 'Deaths/1M pop',
#        'TotalTests', 'Tests/1M pop', 'WHO Region', 'iso_alpha'],
#       dtype='object')

# %%
# Drop NewCases, NewDeaths, NewRecovered rows from dataset1

dataset1.drop(['NewCases', 'NewDeaths', 'NewRecovered'], 
              axis=1, inplace=True)

# Select random set of values from dataset1
dataset1.sample(5)
# Out:
#              Country/Region      Continent   Population  TotalCases  \
# 85                    Gabon         Africa    2230563.0        7787
# 119                Slovakia         Europe    5459915.0        2480
# 188           Liechtenstein         Europe      38139.0          89
# 3                    Russia         Europe  145940924.0      871894
# 191  St. Vincent Grenadines  North America     110976.0          56
#
#      TotalDeaths  TotalRecovered  ActiveCases  Serious,Critical  \
# 85          51.0          5609.0       2127.0              11.0
# 119         29.0          1824.0        627.0               2.0
# 188          1.0            85.0          3.0               NaN
# 3        14606.0        676357.0     180931.0            2300.0
# 191          NaN            46.0         10.0               NaN
#
#      Tot Cases/1M pop  Deaths/1M pop  TotalTests  Tests/1M pop WHO Region  \
# 85             3491.0           23.0     85369.0       38272.0     Africa
# ...

# %%
# Import create_table Figure Factory

from plotly.figure_factory import create_table

colorscale = [[0, '#4d004c'], [.5, '#f2e5ff'], [1, '#ffffff']]
table = create_table(dataset1.head(15), colorscale=colorscale)
py.iplot(table)

# %%
fig1 = px.bar(dataset1.head(15), x = 'Country/Region', 
       y = 'TotalCases',color = 'TotalCases', 
       height = 500,hover_data = ['Country/Region', 'Continent'])


# Save the figure as an image
fig1.write_image("plot1.png")

# Display the saved image
from IPython.display import Image
Image("plot1.png")

# %%
fig2 = px.bar(dataset1.head(15), x = 'Country/Region', y = 'TotalCases',
       color = 'TotalDeaths', height = 500,
       hover_data = ['Country/Region', 'Continent'])


# Save the figure as an image
fig2.write_image("plot2.png")

# Display the saved image
from IPython.display import Image
Image("plot2.png")

# %%
fig3 = px.bar(dataset1.head(15), x = 'Country/Region', y = 'TotalCases',
       color = 'TotalDeaths', height = 500,
       hover_data = ['Country/Region', 'Continent'])


# Save the figure as an image
fig3.write_image("plot3.png")

# Display the saved image
from IPython.display import Image
Image("plot3.png")

# %%
fig4 = px.bar(dataset1.head(15), x = 'Country/Region', y = 'TotalCases',
       color = 'TotalTests', height = 500, hover_data = ['Country/Region', 'Continent'])


# Save the figure as an image
fig4.write_image("plot4.png")

# Display the saved image
from IPython.display import Image
Image("plot4.png")

# %%
fig5 = px.bar(dataset1.head(15), x = 'TotalTests', y = 'Country/Region',
       color = 'TotalTests',orientation ='h',  height = 500,
       hover_data = ['Country/Region', 'Continent'])


# Save the figure as an image
fig5.write_image("plot5.png")

# Display the saved image
from IPython.display import Image
Image("plot5.png")

# %%
fig6 = px.bar(dataset1.head(15), x = 'TotalTests', y = 'Continent',
       color = 'TotalTests',orientation ='h',  height = 500, 
       hover_data = ['Country/Region', 'Continent'])


# Save the figure as an image
fig6.write_image("plot6.png")

# Display the saved image
from IPython.display import Image
Image("plot6.png")

# %%
fig7 = px.scatter(dataset1, x='Continent',y='TotalCases', 
           hover_data=['Country/Region', 'Continent'], 
           color='TotalCases', size='TotalCases', size_max=80, width=1200)


# Save the figure as an image
fig7.write_image("plot7.png")

# Display the saved image
from IPython.display import Image
Image("plot7.png")

# %%
fig8 = px.scatter(dataset1.head(57), x='Continent',y='TotalCases', 
           hover_data=['Country/Region', 'Continent'], 
           color='TotalCases', size='TotalCases', size_max=80, log_y=True, width=1200)


# Save the figure as an image
fig8.write_image("plot8.png")

# Display the saved image
from IPython.display import Image
Image("plot8.png")

# %%
fig9 = px.scatter(dataset1.head(54), x='Continent',y='TotalTests', 
           hover_data=['Country/Region', 'Continent'], 
           color='TotalTests', size='TotalTests', size_max=80, width=1200)


# Save the figure as an image
fig9.write_image("plot9.png")

# Display the saved image
from IPython.display import Image
Image("plot9.png")

# %%
fig10 = px.scatter(dataset1.head(50), x='Continent',y='TotalTests', 
           hover_data=['Country/Region', 'Continent'], 
           color='TotalTests', size='TotalTests', size_max=80, log_y=True, width=1200)


# Save the figure as an image
fig10.write_image("plot10.png")

# Display the saved image
from IPython.display import Image
Image("plot10.png")

# %%
fig11 = px.scatter(dataset1.head(100), x='Country/Region', y='TotalCases', 
           hover_data=['Country/Region', 'Continent'],
           color='TotalCases', size='TotalCases', size_max=80)


# Save the figure as an image
fig11.write_image("plot11.png")

# Display the saved image
from IPython.display import Image
Image("plot11.png")

# %%
fig12 = px.scatter(dataset1.head(30), x='Country/Region', y='TotalCases', 
           hover_data=['Country/Region', 'Continent'],
           color='Country/Region', size='TotalCases', size_max=80, log_y=True)


# Save the figure as an image
fig12.write_image("plot12.png")

# Display the saved image
from IPython.display import Image
Image("plot12.png")

# %%
fig13 = px.scatter(dataset1.head(10), x='Country/Region', y= 'TotalDeaths', 
           hover_data=['Country/Region', 'Continent'],
           color='Country/Region', size= 'TotalDeaths', size_max=80)


# Save the figure as an image
fig13.write_image("plot13.png")

# Display the saved image
from IPython.display import Image
Image("plot13.png")

# %%
fig14 = px.scatter(dataset1.head(30), x='Country/Region', y= 'Tests/1M pop', 
           hover_data=['Country/Region', 'Continent'],
           color='Country/Region', size= 'Tests/1M pop', size_max=80)


# Save the figure as an image
fig14.write_image("plot14.png")

# Display the saved image
from IPython.display import Image
Image("plot14.png")

# %%
fig15 = px.scatter(dataset1.head(30), x='Country/Region', y= 'Tests/1M pop', 
           hover_data=['Country/Region', 'Continent'],
           color='Tests/1M pop', size= 'Tests/1M pop', size_max=80)


# Save the figure as an image
fig15.write_image("plot15.png")

# Display the saved image
from IPython.display import Image
Image("plot15.png")

# %%
fig16 = px.scatter(dataset1.head(30), x='TotalCases', y= 'TotalDeaths', 
           hover_data=['Country/Region', 'Continent'],
           color='TotalDeaths', size= 'TotalDeaths', size_max=80)


# Save the figure as an image
fig16.write_image("plot16.png")

# Display the saved image
from IPython.display import Image
Image("plot16.png")

# %%
fig17 = px.scatter(dataset1.head(30), x='TotalCases', y= 'TotalDeaths', 
           hover_data=['Country/Region', 'Continent'],
           color='TotalDeaths', size= 'TotalDeaths', size_max=80, 
           log_x=True, log_y=True)


# Save the figure as an image
fig17.write_image("plot17.png")

# Display the saved image
from IPython.display import Image
Image("plot17.png")

# %%
fig18 = px.scatter(dataset1.head(30), x='TotalTests', y= 'TotalCases', 
           hover_data=['Country/Region', 'Continent'],
           color='TotalTests', size= 'TotalTests', size_max=80, 
           log_x=True, log_y=True)


# Save the figure as an image
fig18.write_image("plot18.png")

# Display the saved image
from IPython.display import Image
Image("plot18.png")

# %%
fig19 = px.bar(dataset2, x="Date", y="Confirmed", color="Confirmed", 
       hover_data=["Confirmed", "Date", "Country/Region"], height=400)


# Save the figure as an image
fig19.write_image("plot19.png")

# Display the saved image
from IPython.display import Image
Image("plot19.png")

# %%
fig20 = px.bar(dataset2, x="Date", y="Confirmed", color="Confirmed", 
       hover_data=["Confirmed", "Date", "Country/Region"],log_y=True, height=400)


# Save the figure as an image
fig20.write_image("plot20.png")

# Display the saved image
from IPython.display import Image
Image("plot20.png")

# %%
fig21 = px.bar(dataset2, x="Date", y="Deaths", color="Deaths", 
       hover_data=["Confirmed", "Date", "Country/Region"],
       log_y=False, height=400)


# Save the figure as an image
fig21.write_image("plot21.png")

# Display the saved image
from IPython.display import Image
Image("plot21.png")

# %%
df_US= dataset2.loc[dataset2["Country/Region"]=="US"]

# %%
fig22 = px.bar(df_US, x="Date", y="Confirmed", color="Confirmed", height=400)


# Save the figure as an image
fig22.write_image("plot22.png")

# Display the saved image
from IPython.display import Image
Image("plot22.png")

# %%
fig23 = px.bar(df_US, x="Date", y="Confirmed", color="Confirmed", height=400)


# Save the figure as an image
fig23.write_image("plot23.png")

# Display the saved image
from IPython.display import Image
Image("plot23.png")

# %%
fig24 = px.line(df_US,x="Date", y="Recovered", height=400)


# Save the figure as an image
fig24.write_image("plot24.png")

# Display the saved image
from IPython.display import Image
Image("plot24.png")

# %%
fig25 = px.line(df_US,x="Date", y="Deaths", height=400)


# Save the figure as an image
fig25.write_image("plot25.png")

# Display the saved image
from IPython.display import Image
Image("plot25.png")

# %%
fig26 = px.line(df_US,x="Date", y="Confirmed", height=400)


# Save the figure as an image
fig26.write_image("plot26.png")

# Display the saved image
from IPython.display import Image
Image("plot26.png")

# %%
fig27 = px.line(df_US,x="Date", y="New cases", height=400)


# Save the figure as an image
fig27.write_image("plot27.png")

# Display the saved image
from IPython.display import Image
Image("plot27.png")

# %%
fig28 = px.bar(df_US,x="Date", y="New cases", height=400)


# Save the figure as an image
fig28.write_image("plot28.png")

# Display the saved image
from IPython.display import Image
Image("plot28.png")

# %%
fig29 = px.scatter(df_US, x="Confirmed", y="Deaths", height=400)


# Save the figure as an image
fig29.write_image("plot29.png")

# Display the saved image
from IPython.display import Image
Image("plot29.png")

# %%
fig30 = px.choropleth(dataset2,
              locations="iso_alpha",
              color="Confirmed",
              hover_name="Country/Region", 
              color_continuous_scale="Blues",
              animation_frame="Date")


# Save the figure as an image
fig30.write_image("plot30.png")

# Display the saved image
from IPython.display import Image
Image("plot30.png")

# %%
fig31 = px.choropleth(dataset2,
              locations='iso_alpha',
              color="Deaths",
              hover_name="Country/Region",
              color_continuous_scale="Viridis",
              animation_frame="Date" )


# Save the figure as an image
fig31.write_image("plot31.png")

# Display the saved image
from IPython.display import Image
Image("plot31.png")

# %%
fig32 = px.choropleth(dataset2,
              locations='iso_alpha',
              color="Recovered",
              hover_name="Country/Region",
              color_continuous_scale="RdYlGn",
              projection="natural earth",
              animation_frame="Date" )


# Save the figure as an image
fig32.write_image("plot32.png")

# Display the saved image
from IPython.display import Image
Image("plot32.png")

# %%
fig33 = px.bar(dataset2, x="WHO Region", y="Confirmed", color="WHO Region", 
       animation_frame="Date", hover_name="Country/Region")


# Save the figure as an image
fig33.write_image("plot33.png")

# Display the saved image
from IPython.display import Image
Image("plot33.png")

# %%
dataset3= pd.read_csv("coviddeath.csv")
dataset3.head()
# Out:
#    Data as of  Start Week    End Week State       Condition Group  \
# 0  08/30/2020  02/01/2020  08/29/2020    US  Respiratory diseases
# 1  08/30/2020  02/01/2020  08/29/2020    US  Respiratory diseases
# 2  08/30/2020  02/01/2020  08/29/2020    US  Respiratory diseases
# 3  08/30/2020  02/01/2020  08/29/2020    US  Respiratory diseases
# 4  08/30/2020  02/01/2020  08/29/2020    US  Respiratory diseases
#
#                  Condition ICD10_codes Age Group  Number of COVID-19 Deaths  \
# 0  Influenza and pneumonia     J09-J18      0-24                      122.0
# 1  Influenza and pneumonia     J09-J18     25-34                      596.0
# 2  Influenza and pneumonia     J09-J18     35-44                     1521.0
# 3  Influenza and pneumonia     J09-J18     45-54                     4186.0
# 4  Influenza and pneumonia     J09-J18     55-64                    10014.0
#
#   Flag
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
dataset3.tail()
# Out:
#        Data as of  Start Week    End Week State           Condition Group  \
# 12255  08/30/2020  02/01/2020  08/29/2020    YC  Coronavirus Disease 2019
# 12256  08/30/2020  02/01/2020  08/29/2020    YC  Coronavirus Disease 2019
# 12257  08/30/2020  02/01/2020  08/29/2020    YC  Coronavirus Disease 2019
# 12258  08/30/2020  02/01/2020  08/29/2020    YC  Coronavirus Disease 2019
# 12259  08/30/2020  02/01/2020  08/29/2020    YC  Coronavirus Disease 2019
#
#       Condition ICD10_codes   Age Group  Number of COVID-19 Deaths  \
# 12255  COVID-19        U071       65-74                     5024.0
# 12256  COVID-19        U071       75-84                     5381.0
# 12257  COVID-19        U071         85+                     4841.0
# 12258  COVID-19        U071  Not stated                        NaN
# 12259  COVID-19        U071    All ages                    20628.0
#
#                                   Flag
# 12255                              NaN
# ...

# %%
dataset3.groupby(["Condition"]).count()
# Out:
#                                                     Data as of  Start Week  \
# Condition
# Adult respiratory distress syndrome                        540         540
# All other conditions and causes (residual)                 540         540
# Alzheimer disease                                          530         530
# COVID-19                                                   540         540
# Cardiac arrest                                             520         520
# Cardiac arrhythmia                                         540         540
# Cerebrovascular diseases                                   530         530
# Chronic lower respiratory diseases                         540         540
# Diabetes                                                   540         540
# Heart failure                                              540         540
# Hypertensive diseases                                      540         540
# ...

# %%
# import word cloud
from wordcloud import WordCloud

sentences = dataset3["Condition"].tolist()
sentences_as_a_string = ' '.join(sentences)


# Convert the string into WordCloud
plt.figure(figsize=(20, 20))
plt.imshow(WordCloud().generate(sentences_as_a_string))

# %%
column2_tolist= dataset3["Condition Group"].tolist()

# Convert the list to one single string
column_to_string= " ".join(column2_tolist)

# Convert the string into WordCloud
plt.figure(figsize=(20,20))
plt.imshow(WordCloud().generate(column_to_string))
